# %%
def household_chatbot(user_input):

    user_input = user_input.lower()


    if "tidy" in user_input:
        response = "Sure, cleaning is important! Consider starting with one room at a time to keep things organized."
    elif "cook" in user_input:
        response = "Cooking can be fun! Do you have a specific dish in mind, or would you like a recipe suggestion?"
    elif "shopping" in user_input:
        response = "For grocery shopping, make a list of what you need to avoid forgetting anything. Do you need help with a specific grocery item?"
    elif "how to replace bulb" in user_input:
        response = "To replace a light bulb, make sure the power is off, unscrew the old bulb, and screw in the new one. If it's a different type, check the wattage."
    elif "how do I clean stainless steel appliances?" in user_input:
        response = "Use a mixture of mild soap and water, and wipe with a soft cloth in the direction of the grain."
    elif "what's the best way to organize a closet?" in user_input:
        response = "Start by decluttering, use hangers for clothes, and consider storage bins for accessories."
    elif "can you suggest a quick dinner recipe?" in user_input:
        response = "Try a simple pasta dish with olive oil, garlic, cherry tomatoes,\n and fresh basil or you can fry prawns and eat with noodles its taste delicious."
    elif "how do I remove carpet stains?" in user_input or "how to remove carpet stains?" in user_input:
        response = "Blot the stain with a mixture of vinegar and water, then gently scrub with a cloth."
    elif "what's an efficient way to mop the floor?" in user_input or "how to mop the floor efficiently?" in user_input:
        response = "Mix a floor cleaner with warm water and use a microfiber mop for a streak-free finish."
    elif "Any tips for organizing kitchen cabinets?" in user_input or "how to organize kitchen cabinets?" in user_input:
        response = "Group similar items together and use storage containers to maximize space."
    elif "How do I clean a microwave?" in user_input or "how to clean microwave" in user_input or "what is the best way to clean microwave" in user_input:
        response = " Heat a bowl of water with lemon slices for a few minutes, then wipe down the interior."
    elif "can you recommend a budget-friendly grocery list?" in user_input or "list the grocery item" in user_input:
        response = "Rice ,\n Beans ,\n Pasta ,\n Canned vegetables ,\n Seasonal fruits ,\n Bread ,\n Milk ,\n Eggs ,\n Butter ,\n Cheese ,\n Yogurt ,\n Beef ,\n Fish ,\n Rice ,\n Pasta ,\n Canned beans ,\n Lentils ,\n Oats"
    elif "how do I clean a coffee maker?" in user_input or "how to clean coffee maker?" in user_input:
        response = "Run a mixture of equal parts water and vinegar through the coffee maker, followed by a few cycles of plain water."
    elif "Can you recommend a DIY natural air freshener?" in user_input or "make a natural DIY air freshner?" in user_input:
        response = "Combine water, baking soda, and a few drops of essential oil in a spray bottle."
    elif "Can you suggest a simple meal prep plan?" in user_input or "suggest a basic meal" in user_input:
        response = "Prep basics like grilled chicken, roasted vegetables, and quinoa for easy and healthy meals."
    elif "What's an easy recipe for a one-pot meal?" in user_input or "one-pot meal" in user_input:
        response = "Try a simple chili or pasta dish where all ingredients cook together in one pot."
    elif "Can you suggest a grocery list for a gluten-free diet?" in user_input or "suggest a list for gluten-free diet" in user_input:
        response = "Include gluten-free grains, vegetables, fruits, and certified gluten-free products."
    elif "how to clean bathroom?" in user_input:
        response = "Clean surfaces regularly, use a squeegee on shower doors, and wash bath mats and towels."
    elif "How do I start a vegetable garden?" in user_input or "how to start vegetable gardening" in user_input:
        response = " Choose a sunny location, prepare the soil, and select vegetables suitable for your region."
    elif "What is the best way to deal with garden pests?" in user_input or "how to compete with garden pests" in user_input:
        response = " Use natural remedies like neem oil or companion planting, and regularly inspect plants for signs of pests."
    elif "How do I compost at home?" in user_input or "how to grow plants at home" in user_input:
        response = " Collect kitchen scraps like fruit and vegetable peels, add brown materials like leaves, and turn the compost regularly."
    elif "Can you suggest a natural fertilizer for my garden?" in user_input or "suggest a natural fertilizer for my garden" in user_input:
        response = "Compost, manure tea, and diluted fish emulsion are effective natural fertilizers."
    elif "How can I attract butterflies to my garden?" in user_input:
        response = " Plant nectar-rich flowers, provide host plants for caterpillars, and avoid pesticide use."
    elif "Can you suggest a recipe for a homemade salad dressing?" in user_input or "what is the best salad dressing?" in user_input or "sallad dressing" in user_input:
        response = "Mix olive oil, balsamic vinegar, Dijon mustard, honey, and salt for a tasty vinaigrette."
    elif "suggest a salad recipe" in user_input or "salad recipe" in user_input:
        response = "Feel free to customize the salad by adding ingredients like avocados, olives, nuts, or grilled chicken for added protein. \nThis recipe is a versatile starting point, and you can adjust it based on your taste preferences and the ingredients you have on hand."
    elif "recipe of aglio e olio pasta" in user_input or "pasta recipe" in user_input:
        response = "Begin by cooking 8 ounces of spaghetti according to package instructions.\n While the spaghetti is cooking, sauté four thinly sliced cloves of garlic and half a teaspoon of red pepper flakes in a quarter cup of extra-virgin olive oil over medium heat until the garlic turns golden,\n taking care not to burn it. Once the spaghetti is cooked, drain it and toss it in the garlic-infused oil.\n Season with salt and black pepper to taste, and garnish with chopped fresh parsley.\n Optionally, top it with grated Parmesan cheese. This simple and flavorful Spaghetti Aglio e Olio is ready to be served immediately."
    elif "How do I start a vegetable garden?" in user_input or "how to start vegetable gardening" in user_input:
        response = " Choose a sunny location, prepare the soil, and select vegetables suitable for your region."
    elif "recipe of soup" in user_input or "lentil soup" in user_input:
        response = "Start by sautéing chopped onions, carrots, and celery in olive oil until softened. Add minced garlic, cumin, coriander,\n and dried thyme, allowing the spices to toast for a minute. Pour in vegetable broth, canned diced tomatoes,\n and rinsed green or brown lentils. Bring the soup to a boil, then reduce the heat and simmer until the lentils are tender.\n Season with salt and black pepper to taste. Stir in fresh spinach until wilted just before serving.\n Ladle this nutritious Vegetarian Lentil Soup into bowls,\n and if desired, squeeze fresh lemon juice over the top for a burst of brightness."
    elif "recipe of chicken biyani" in user_input or "chicken biryani" in user_input:
        response = "Begin by marinating chicken pieces in a mixture of yogurt, ginger-garlic paste, red chili powder, turmeric, \n and biryani masala. In a separate pot, parboil Basmati rice with whole spices like cardamom, \n cinnamon, and cloves. In a large heavy-bottomed pan, layer the marinated chicken and partially cooked rice, \n alternating and finishing with a layer of rice on top. Garnish with fried onions, chopped mint, and coriander leaves. \n Sprinkle saffron-infused milk over the layers. Cover and cook on low heat until the chicken is tender and the rice is fully cooked. \n Gently fluff the biryani with a fork, ensuring the layers remain intact. Serve this aromatic Chicken Biryani with raita for a delightful meal."
    elif  "how do  i boil an egg?" in user_input:
        response ="To boil an egg, place it in a pot of cold water. Bring the water to a boil, then reduce the heat and simmer for about 9-12 minutes for a hard-boiled egg."
    elif   "how do i chop onions?" in user_input:
        response = "To chop an onion, cut off the ends, peel off the skin, and slice it in half. Place each half flat-side down and make horizontal cuts, then vertical cuts."
    elif  "how do i make coffee?" in user_input:
        response ="To make coffee, grind coffee beans to your desired consistency, add them to a coffee maker with water, and brew according to the machine's instructions."
    elif  "how do i clean a coffee maker?" in user_input:
       response = "To clean a coffee maker, mix equal parts water and vinegar, pour it into the water chamber, and run a brewing cycle. Then, run a cycle with clean water to rinse."
    elif  "how do i cook rice?" in user_input:
        response = "To cook rice, rinse the rice under cold water, then add it to a pot with the appropriate amount of water or broth. Bring to a boil, then reduce heat to low, cover, and simmer until the liquid is absorbed."
    elif  "how do i cook pasta?" in user_input:
        response = "To cook pasta, bring a pot of salted water to a boil, then add the pasta. Cook according to the package instructions until al dente, then drain and serve with your favorite sauce."
    elif  "how do i make scrambled eggs?" in user_input:
        response = "To make scrambled eggs, crack eggs into a bowl and whisk until well beaten. Heat a non-stick skillet over medium heat, add the eggs, and cook, stirring occasionally, until set."
    elif "how do i make pancakes?" in user_input:
        response = "To make pancakes, combine flour, sugar, baking powder, salt, milk, eggs, and melted butter in a bowl. Heat a non-stick skillet over medium heat, pour batter onto the skillet, and cook until bubbles form, then flip and cook until golden brown."
    elif  "how do i make mashed potatoes?" in user_input:
        response = "To make mashed potatoes, peel and chop potatoes, then boil them until tender. Drain the potatoes and mash them with butter, milk, salt, and pepper until smooth."
    elif  "how do i roast vegetables?" in user_input:
        response ="To roast vegetables, toss them with olive oil, salt, and pepper, then spread them in a single layer on a baking sheet. Roast in a preheated oven until tender and caramelized."
    elif  "how do i make a salad dressing?" in user_input:
        response ="To make a salad dressing, whisk together oil, vinegar or lemon juice, mustard, honey or maple syrup, salt, and pepper until emulsified."
    elif  "how do i grill chicken?" in user_input:
       response = "To grill chicken, marinate chicken breasts or thighs in your favorite marinade, then grill over medium-high heat until cooked through, about 6-8 minutes per side."
    elif  "how do i bake cookies?" in user_input:
         response ="To bake cookies, preheat your oven, then cream together butter and sugar in a bowl. Add eggs and vanilla, then mix in flour, baking soda, and salt. Drop spoonfuls of dough onto a baking sheet and bake until golden brown."
    elif "how do i make homemade pizza dough?" in user_input:
        response ="To make homemade pizza dough, combine flour, yeast, salt, sugar, and water in a bowl. Knead the dough until smooth, then let it rise until doubled in size."
    elif "how do i make tomato sauce?" in user_input:
        response ="To make tomato sauce, sauté onions and garlic in olive oil until soft. Add canned tomatoes, herbs, salt, and pepper, then simmer until thickened."
    elif "how do i make a grilled cheese sandwich?" in user_input:
        response ="To make a grilled cheese sandwich, spread butter on two slices of bread. Place cheese between the slices, then grill in a skillet over medium heat until golden brown and crispy."
    elif  "how do i make a smoothie?" in user_input:
        response ="To make a smoothie, blend together your choice of fruit, yogurt, milk or juice, and ice until smooth."
    elif "how do i make guacamole?" in user_input:
        response ="To make guacamole, mash ripe avocados with lime juice, salt, pepper, chopped onions, tomatoes, cilantro, and jalapeños until combined."
    elif  "how do i make homemade pasta?" in user_input:
       response ="To make homemade pasta, combine flour and eggs in a bowl, then knead until smooth. Roll out the dough and cut into desired shapes, then cook in boiling water until al dente."
    elif  "how do i make a grilled steak?" in user_input:
         response ="To make a grilled steak, season the steak with salt and pepper, then grill over high heat until desired doneness is reached."
    elif  "how do i make a fruit salad?" in user_input:
      response ="To make a fruit salad, chop up your favorite fruits and toss them together in a bowl. Optional: add a squeeze of lemon juice or a drizzle of honey for extra flavor."
    elif "how do i make a vegetable stir-fry?" in user_input:
        response ="To make a vegetable stir-fry, heat oil in a wok or skillet, then add chopped vegetables and stir-fry until tender-crisp. Add your choice of sauce and stir until heated through."
    elif "how do i make sushi rolls?" in user_input:
       response ="To make sushi rolls, spread cooked sushi rice onto a sheet of nori, then add your choice of fillings (like raw fish, avocado, cucumber, or cooked shrimp). Roll tightly and slice into pieces."
    elif "how do i make chicken soup?" in user_input:
        response ="To make chicken soup, simmer chicken breasts or thighs with vegetables, herbs, and chicken broth until the chicken is cooked through and the flavors have melded together."
    elif "how do i make a basic vinaigrette?" in user_input:
       response ="To make a basic vinaigrette, whisk together olive oil, vinegar, mustard, salt, and pepper until emulsified."
    elif "how do i make homemade bread?" in user_input:
     response ="To make homemade bread, combine flour, yeast, salt, sugar, and water in a bowl. Knead the dough until smooth, then let it rise until doubled in size before baking."
    elif  "how do i make a cheese omelette?" in user_input:
      response =  "To make a cheese omelette, beat eggs in a bowl, then pour into a heated skillet. Sprinkle grated cheese over the eggs and cook until set, then fold in half and serve."
    elif "how do i make spaghetti carbonara?" in user_input:
       response ="To make spaghetti carbonara, cook spaghetti until al dente, then toss with cooked pancetta or bacon, beaten eggs, grated Parmesan cheese, and black pepper."
    elif  "how do i make chicken curry?" in user_input:
      response ="To make chicken curry, sauté onions, garlic, and ginger in oil until soft. Add curry powder, chicken pieces, coconut milk, and tomatoes, then simmer until the chicken is cooked through."
    elif "how do i make homemade soup stock?" in user_input:
       response ="To make homemade soup stock, simmer chicken or beef bones with vegetables, herbs, and water for several hours until rich and flavorful."
    elif "how do i make chocolate chip cookies?" in user_input:
        response ="To make chocolate chip cookies, cream together butter and sugar, then add eggs and vanilla. Mix in flour, baking soda, salt, and chocolate chips, then drop spoonfuls of dough onto a baking sheet and bake until golden brown."
    elif "how do i make a fruit tart?" in user_input:
          response ="To make a fruit tart, bake a pastry crust until golden brown, then fill with pastry cream or custard. Arrange sliced fruit on top and brush with apricot glaze."
    elif  "how do i make mashed avocado toast?" in user_input:
         response ="To make mashed avocado toast, toast bread until golden brown, then spread mashed avocado on top. Sprinkle with salt, pepper, and any desired toppings."
    elif "how do i make chicken Alfredo pasta?" in user_input:
        response ="To make chicken Alfredo pasta, cook pasta until al dente, then toss with cooked chicken, Alfredo sauce, and grated Parmesan cheese until heated through."
    elif "how do i make vegetable lasagna?" in user_input:
        response ="To make vegetable lasagna, layer cooked lasagna noodles with ricotta cheese, marinara sauce, sautéed vegetables, and shredded mozzarella cheese. Repeat the layers and bake until bubbly."
    elif  "how do i make beef tacos?" in user_input:
         response ="To make beef tacos, cook ground beef with taco seasoning until browned and crumbled. Serve in taco shells with shredded lettuce, diced tomatoes, shredded cheese, and salsa."
    elif "how do i make shrimp scampi?" in user_input:
        response ="To make shrimp scampi, sauté shrimp in butter and garlic until pink and opaque. Add lemon juice, white wine, and chopped parsley, then toss with cooked pasta."
    elif "how do i make lemonade?" in user_input:
        response ="To make lemonade, combine freshly squeezed lemon juice, sugar, and water in a pitcher. Stir until the sugar is dissolved, then serve over ice."
    elif  "how do i make a Greek salad?" in user_input:
        response ="To make a Greek salad, toss together chopped lettuce, tomatoes, cucumbers, red onions, Kalamata"


    else:
        response = "I'm sorry, I'm not sure how to help with that. Can you provide more details or ask about another household topic?"

    return response


print("Hello!  I'm your household chatbot. Ask me about household tasks.")
while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("   Goodbye! If you have more questions later, feel free to ask.")
        break

    bot_response = household_chatbot(user_input)
    print("you:", bot_response)
# Out:
# Hello!  I'm your household chatbot. Ask me about household tasks.
